# %% [markdown]
# #**Introduction:**
#
# Cardiovascular diseases (CVDs) are the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide. Four out of 5CVD deaths are due to heart attacks and strokes, and one-third of these deaths occur prematurely in people under 70 years of age. Heart failure is a common event caused by CVDs and this dataset contains 11 features that can be used to predict a possible heart disease.
#
# People with cardiovascular disease or who are at high cardiovascular risk (due to the presence of one or more risk factors such as hypertension, diabetes, hyperlipidaemia or already established disease) need early detection and management wherein a machine learning model can be of great help
#
# #Columns Info:
# 1.Age: age of the patient [years]
#
# 2.Sex: sex of the patient [M: Male, F: Female]
#
# 3.ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
#
# 4.RestingBP: resting blood pressure [mm Hg]
#
# 5.Cholesterol: serum cholesterol [mm/dl]
#
# 6.FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
#
# 7.RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
#
# 8.MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
#
# 9.ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
#
# 10.Oldpeak: oldpeak = ST [Numeric value measured in depression]
#
# 11.Smoking: whether the person is smoking or not [1 for Yes and 0 for No]
# STSlope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
#
# 12.HeartDisease: output class [1: heart disease, 0: Normal]
#
#
# **Final dataset: 927 observations**

# %% [markdown]
# #**Aim**:
# To predict whether the person has Heart Disease or not.
#
# So,Let's get started!

# %% [markdown]
# #**Libraries Involved:**
#
# - Pandas
#
# - Matplotlib
#
# - Seaborn
#
# - Sklearn
#
# - Numpy

# %% [markdown]
# **IMPORTING DATASET:**
#
# First let's upload the target csv file.
#
# let's import the dataset using pandas library and print it accordingly.

# %%
from google.colab import files as f
f.upload()
# Out:
#      <input type="file" id="files-cd59e601-2691-4a92-bda4-c949e8258786" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd59e601-2691-4a92-bda4-c949e8258786">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Heart.csv to Heart.csv
# {'Heart.csv': b'Age,Sex,ChestPainType,RestingBP,Cholesterol,FastingBS,RestingECG,MaxHR,ExerciseAngina,Oldpeak,STSlope,Smoking,HeartDisease\r\n40,M,ATA,140,289,0,Normal,172,N,0,Up,0,0\r\n49,F,NAP,160,180,0,Normal,156,N,1,Flat,0,1\r\n37,M,ATA,130,283,0,ST,98,N,0,Up,1,0\r\n48,F,ASY,138,214,0,Normal,108,Y,1.5,Flat,0,1\r\n54,M,NAP,150,195,0,Normal,122,N,0,Up,0,0\r\n39,M,NAP,120,339,0,Normal,170,N,0,Up,1,0\r\n45,F,ATA,130,237,0,Normal,170,N,0,Up,0,0\r\n54,M,ATA,110,208,0,Normal,142,N,0,Up,1,0\r\n37,M,ASY,140,207,0,Normal,130,Y,1.5,Flat,0,1\r\n48,F,ATA,120,284,0,Normal,120,N,0,Up,1,0\r\n37,F,NAP,130,211,0,Normal,142,N,0,Up,1,0\r\n58,M,ATA,136,164,0,ST,99,Y,2,Flat,1,1\r\n39,M,ATA,120,204,0,Normal,145,N,0,Up,0,0\r\n49,M,ASY,140,234,0,Normal,140,Y,1,Flat,0,1\r\n42,F,NAP,115,211,0,ST,137,N,0,Up,0,0\r\n54,F,ATA,120,273,0,Normal,150,N,1.5,Flat,0,0\r\n38,M,ASY,110,196,0,Normal,166,N,0,Flat,0,1\r\n43,F,ATA,120,201,0,Normal,165,N,0,Up,0,0\r\n60,M,ASY,100,248,0,Normal,125,N,1,Flat,0,1\r\n36,M,ATA,120,267,0,Normal,160,N,3,Flat,0,1\r\n43,F,TA,100,223,0,Normal,142,N,0,Up,0,0\r\n44,M,ATA,120,184,0,Normal,142,N,1,Flat,0,0\r\n49,F,ATA,124,201,0,Normal,164,N,0,Up,1,0\r\n44,M,ATA,150,288,0,Normal,150,Y,3,Flat,0,1\r\n40,M,NAP,130,215,0,Normal,138,N,0,Up,0,0\r\n36,M,NAP,130,209,0,Normal,178,N,0,Up,1,0\r\n53,M,ASY,124,260,0,ST,112,Y,3,Flat,0,0\r\n52,M,ATA,120,284,0,Normal,118,N,0,Up,1,0\r\n53,F,ATA,113,468,0,Normal,127,N,0,Up,0,0\r\n51,M,ATA,125,188,0,Normal,145,N,0,Up,1,0\r\n53,M,NAP,145,518,0,Normal,130,N,0,Flat,0,1\r\n56,M,NAP,130,167,0,Normal,114,N,0,Up,0,0\r\n54,M,ASY,125,224,0,Normal,122,N,2,Flat,0,1\r\n41,M,ASY,130,172,0,ST,130,N,2,Flat,0,1\r\n43,F,ATA,150,186,0,Normal,154,N,0,Up,0,0\r\n32,M,ATA,125,254,0,Normal,155,N,0,Up,0,0\r\n65,M,ASY,140,306,1,Normal,87,Y,1.5,Flat,0,1\r\n41,F,ATA,110,250,0,ST,142,N,0,Up,0,0\r\n48,F,ATA,120,177,1,ST,148,N,0,Up,0,0\r\n48,F,ASY,150,227,0,Normal,130,Y,1,Flat,0,0\r\n54,F,ATA,150,230,0,Normal,130,N,0,Up,1,0\r\n54,F,NAP,130,294,0,ST,100,Y,0,Flat,1,1\r\n35,M,ATA,150,264,0,Normal,168,N,0,Up,1,0\r\n52,M,NAP,140,259,0,ST,170,N,0,Up,0,0\r\n43,M,ASY,120,175,0,Normal,120,Y,1,Flat,0,1\r\n59,M,NAP,130,318,0,Normal,120,Y,1,Flat,1,0\r\n37,M,ASY,120,223,0,Normal,168,N,0,Up,0,0\r\n50,M,ATA,140,216,0,Normal,170,N,0,Up,1,0\r\n36,M,NAP,112,340,0,Normal,184,N,1,Flat,0,0\r\n41,M,ASY,110,289,0,Normal,170,N,0,Flat,0,1\r\n50,M,ASY,130,233,0,Normal,121,Y,2,Flat,0,1\r\n47,F,ASY,120,205,0,Normal,98,Y,2,Flat,0,1\r\n45,M,ATA,140,224,1,Normal,122,N,0,Up,0,0\r\n41,F,ATA,130,245,0,Normal,150,N,0,Up,0,0\r\n52,F,ASY,130,180,0,Normal,140,Y,1.5,Flat,1,0\r\n51,F,ATA,160,194,0,Normal,170,N,0,Up,0,0\r\n31,M,ASY,120,270,0,Normal,153,Y,1.5,Flat,1,1\r\n58,M,NAP,130,213,0,ST,140,N,0,Flat,1,1\r\n54,M,ASY,150,365,0,ST,134,N,1,Up,1,0\r\n52,M,ASY,112,342,0,ST,96,Y,1,Flat,1,1\r\n49,M,ATA,100,253,0,Normal,174,N,0,Up,0,0\r\n43,F,NAP,150,254,0,Normal,175,N,0,Up,0,0\r\n45,M,ASY,140,224,0,Normal,144,N,0,Up,1,0\r\n46,M,ASY,120,277,0,Normal,125,Y,1,Flat,0,1\r\n50,F,ATA,110,202,0,Normal,145,N,0,Up,0,0\r\n37,F,ATA,120,260,0,Normal,130,N,0,Up,1,0\r\n45,F,ASY,132,297,0,Normal,144,N,0,Up,0,0\r\n32,M,ATA,110,225,0,Normal,184,N,0,Up,1,0\r\n52,M,ASY,160,246,0,ST,82,Y,4,Flat,0,1\r\n44,M,ASY,150,412,0,Normal,170,N,0,Up,0,0\r\n57,M,ATA,140,265,0,ST,145,Y,1,Flat,1,1\r\n44,M,ATA,130,215,0,Normal,135,N,0,Up,1,0\r\n52,M,ASY,120,182,0,Normal,150,N,0,Flat,1,1\r\n44,F,ASY,120,218,0,ST,115,N,0,Up,1,0\r\n55,M,ASY,140,268,0,Normal,128,Y,1.5,Flat,1,1\r\n46,M,NAP,150,163,0,Normal,116,N,0,Up,1,0\r\n32,M,ASY,118,529,0,Normal,130,N,0,Flat,1,1\r\n35,F,ASY,140,167,0,Normal,150,N,0,Up,0,0\r\n52,M,ATA,140,100,0,Normal,138,Y,0,Up,1,0\r\n49,M,ASY,130,206,0,Normal,170,N,0,Flat,0,1\r\n55,M,NAP,110,277,0,Normal,160,N,0,Up,0,0\r\n54,M,ATA,120,238,0,Normal,154,N,0,Up,1,0\r\n63,M,ASY,150,223,0,Normal,115,N,0,Flat,0,1\r\n52,M,ATA,160,196,0,Normal,165,N,0,Up,0,0\r\n56,M,ASY,150,213,1,Normal,125,Y,1,Flat,0,1\r\n66,M,ASY,140,139,0,Normal,94,Y,1,Flat,0,1\r\n65,M,ASY,170,263,1,Normal,112,Y,2,Flat,0,1\r\n53,F,A ...

# %%
import pandas as pd
df = pd.read_csv("Heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  ...  Oldpeak  STSlope Smoking  HeartDisease
# 0     40   M           ATA        140  ...      0.0       Up       0             0
# 1     49   F           NAP        160  ...      1.0     Flat       0             1
# 2     37   M           ATA        130  ...      0.0       Up       1             0
# 3     48   F           ASY        138  ...      1.5     Flat       0             1
# 4     54   M           NAP        150  ...      0.0       Up       0             0
# ..   ...  ..           ...        ...  ...      ...      ...     ...           ...
# 922   55   F            TA        112  ...      1.4     Down       1             0
# 923   78   F           ASY        145  ...      3.5     Flat       0             1
# 924   67   F           ASY        134  ...      1.6     Flat       1             1
# 925   67   M           ATA        132  ...      0.0     Down       0             0
# 926   48   F           NAP        133  ...      1.0       Up       1             0
#
# [927 rows x 13 columns]

# %% [markdown]
# #**KNOWING ABOUT DATASET**
# Now we explore the dataset for better understanding the data for further steps.

# %% [markdown]
# Describing data gives the statistic attributes.

# %%
df.describe()
# Out:
#               Age   RestingBP  ...     Smoking  HeartDisease
# count  927.000000  927.000000  ...  927.000000    927.000000
# mean    53.590076  132.425027  ...    0.321467      0.553398
# std      9.467931   18.484029  ...    0.467292      0.497409
# min     28.000000    0.000000  ...    0.000000      0.000000
# 25%     47.000000  120.000000  ...    0.000000      0.000000
# 50%     54.000000  130.000000  ...    0.000000      1.000000
# 75%     60.000000  140.000000  ...    1.000000      1.000000
# max     78.000000  200.000000  ...    1.000000      1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# Info tells us brief like column names,type of values,null or not and also range.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927 entries, 0 to 926
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             927 non-null    int64
#  1   Sex             927 non-null    object
#  2   ChestPainType   927 non-null    object
#  3   RestingBP       927 non-null    int64
#  4   Cholesterol     927 non-null    int64
#  5   FastingBS       927 non-null    int64
#  6   RestingECG      927 non-null    object
#  7   MaxHR           927 non-null    int64
#  8   ExerciseAngina  927 non-null    object
#  9   Oldpeak         927 non-null    float64
#  10  STSlope         927 non-null    object
#  11  Smoking         927 non-null    int64
#  12  HeartDisease    927 non-null    int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 94.3+ KB

# %% [markdown]
# Here is the total count of rows and columns

# %%
row_count = df.shape[0]
column_count = df.shape[1]
print("There are {} rows and {} columns in the dataset.".format(row_count,column_count))
# Out:
# There are 927 rows and 13 columns in the dataset.

# %% [markdown]
# Now let's print(first five rows)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  ...  Oldpeak  STSlope Smoking  HeartDisease
# 0   40   M           ATA        140  ...      0.0       Up       0             0
# 1   49   F           NAP        160  ...      1.0     Flat       0             1
# 2   37   M           ATA        130  ...      0.0       Up       1             0
# 3   48   F           ASY        138  ...      1.5     Flat       0             1
# 4   54   M           NAP        150  ...      0.0       Up       0             0
#
# [5 rows x 13 columns]

# %% [markdown]
# Now print(last five rows)

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  ...  Oldpeak  STSlope Smoking  HeartDisease
# 922   55   F            TA        112  ...      1.4     Down       1             0
# 923   78   F           ASY        145  ...      3.5     Flat       0             1
# 924   67   F           ASY        134  ...      1.6     Flat       1             1
# 925   67   M           ATA        132  ...      0.0     Down       0             0
# 926   48   F           NAP        133  ...      1.0       Up       1             0
#
# [5 rows x 13 columns]

# %% [markdown]
# FILTERING DATASET

# %% [markdown]
# First step of filtering is dropping NaN values from the dataset so that we get clarity on the dataset to perfrm required operations.

# %%
df.dropna()
if df.shape[0]==row_count and df.shape[1]==column_count:
  print("There are no NaN values")
else:
  print("NaN values are dropped successfully!")
# Out:
# There are no NaN values

# %% [markdown]
# Visualizing HeartDisease with Age and Cholesterol.

# %%
import seaborn as sb
import matplotlib.pyplot as plt
sb.lineplot(x="Cholesterol",y="Age",data=df,hue="HeartDisease")
plt.title("Heart Disease")
plt.legend(labels=["No","Yes"])

# %% [markdown]
# Let's know male count and female count

# %%
sb.countplot(x="Sex",data=df)

# %% [markdown]
# Heat Map for relationship between data.

# %%
data = df.corr()
sb.heatmap(data,cmap=None)

# %% [markdown]
# Let's print all the data in one graph using pairplot from seaborn.

# %%
sb.pairplot(df,diag_kind="kde",hue="HeartDisease")

# %%
fig=plt.figure(figsize=(11,6))
sb.countplot(x='Sex',hue='HeartDisease',data=df)

# %%
fig=plt.figure(figsize=(11,6))
sb.kdeplot(df['Age'],hue = df['HeartDisease'])

# %%
sb.jointplot(x="MaxHR",y="RestingBP",data=df)

# %%
sb.scatterplot(x="MaxHR",y="RestingBP",data=df)

# %%
sb.lmplot(x="MaxHR",y="Age",data=df)

# %% [markdown]
# #**SHAPING DATASET**:
# columns that have categorical variables are Sex, ChestPainType, RestingECG, ExerciseAngina, STSlope.
#
# Replacing all categorical variables with numbers for performing Linear Regression.

# %%
df["Sex"].replace("F",0,inplace=True)
df["Sex"].replace("M",1,inplace=True)
df["STSlope"].replace("Up",0,inplace=True)
df["STSlope"].replace("Flat",1,inplace=True)
df["STSlope"].replace("Down",2,inplace=True)
df["ExerciseAngina"].replace("N",0,inplace=True)
df["ExerciseAngina"].replace("Y",1,inplace=True)

# %%
df["ChestPainType"].replace("ATA",0,inplace=True)
df["ChestPainType"].replace("NAP",1,inplace=True)
df["ChestPainType"].replace("ASY",2,inplace=True)
df["ChestPainType"].replace("TA",3,inplace=True)
df["RestingECG"].replace("Normal",0,inplace=True)
df["RestingECG"].replace("ST",1,inplace=True)
df["RestingECG"].replace("LVH",2,inplace=True)

# %% [markdown]
# #Previewing the data after replacement with numbers.

# %%
df.head(20)
# Out:
#     Age  Sex  ChestPainType  RestingBP  ...  Oldpeak  STSlope  Smoking  HeartDisease
# 0    40    1              0        140  ...      0.0        0        0             0
# 1    49    0              1        160  ...      1.0        1        0             1
# 2    37    1              0        130  ...      0.0        0        1             0
# 3    48    0              2        138  ...      1.5        1        0             1
# 4    54    1              1        150  ...      0.0        0        0             0
# 5    39    1              1        120  ...      0.0        0        1             0
# 6    45    0              0        130  ...      0.0        0        0             0
# 7    54    1              0        110  ...      0.0        0        1             0
# 8    37    1              2        140  ...      1.5        1        0             1
# 9    48    0              0        120  ...      0.0        0        1             0
# 10   37    0              1        130  ...      0.0        0        1             0
# 11   58    1              0        136  ...      2.0        1        1             1
# 12   39    1              0        120  ...      0.0        0        0             0
# 13   49    1              2        140  ...      1.0        1        0             1
# 14   42    0              1        115  ...      0.0        0        0             0
# 15   54    0              0        120  ...      1.5        1        0             0
# 16   38    1              2        110  ...      0.0        1        0             1
# 17   43    0              0        120  ...      0.0        0        0             0
# 18   60    1              2        100  ...      1.0        1        0             1
# 19   36    1              0        120  ...      3.0        1        0             1
#
# [20 rows x 13 columns]

# %%
df.tail(10)
# Out:
#      Age  Sex  ChestPainType  ...  STSlope  Smoking  HeartDisease
# 917   38    1              1  ...        0        0             0
# 918   53    1              2  ...        1        0             1
# 919   51    0              0  ...        0        1             0
# 920   69    1              2  ...        1        0             1
# 921   67    1              2  ...        1        0             1
# 922   55    0              3  ...        2        1             0
# 923   78    0              2  ...        1        0             1
# 924   67    0              2  ...        1        1             1
# 925   67    1              0  ...        2        0             0
# 926   48    0              1  ...        0        1             0
#
# [10 rows x 13 columns]

# %% [markdown]
# #**SPLITING DATASET INTO TRAINING DATA AND TESTING DATA**:
#
# Before building any model we must split the dataset into training and testing data.
#
# training data is used to train the model.
#
# and testing data is used to predict the model after it is trained.

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split as tts
trainX,testX,trainY,testY = tts(X,Y,train_size=0.8,random_state=0)

# %% [markdown]
# #**Building Linear Regression Model**
# Libraries we need to build Linear Regression model is sklearn.

# %%
from sklearn.linear_model import LinearRegression as LR
model = LR().fit(trainX,trainY)

# %% [markdown]
# #**PRECDICTING MODEL**
#
# So,now building model is completed.
#
# let's predict the model with the testing data which is 20% from the actual data.

# %%
Pred = model.predict(testX)
Pred = Pred.round()
sb.distplot(Pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #**Predicting Heart Disease with user input**

# %% [markdown]
# ###**Here iam going to enter the values for prediction from user input.**
# **The values are :**
#
# - Age : 37
# - Sex : M
# - ChestPainType : ATA
# - RestingBP : 130
# - Cholesterol : 283
# - FastingBS : 0
# - RestingECG : ST
# - MaxHR : 98
# - ExerciseAngina : N(which means No)
# - Oldpeak : 0.0
# - STSlope : Up
# - Smoking : Y(which means Yes)

# %%
from google.colab import output
import time

# %%
Age = int(input("Enter Age  :"))
Sex = input("Enter your Gender as M or F :")
CPT = input("Enter chest pain type as ATA or NAP or ASY or TA :")
RBP = int(input("Enter Resting Blood Pressure rate :"))
Chol = int(input("Enter Cholesterol rate :"))
FBS = int(input("Enter FastingBS : "))
REC = input("Enter RestingECG as Normal or ST or LVG :")
MHR = int(input("Enter Maximum Heart Rate :"))
EA = input("Enter ExerciseAngina as Y or N :")
OP = float(input("Enter Oldpeak value :"))
STS = input("Enter ST Slope type as Up or Flat or Down : ")
SMOKE = input("Enter Smoking Status as Y or N : ")
if Sex=="M":
  Sex=1
elif Sex=="F":
  Sex=0
if CPT=="ATA":
  CPT=0
elif CPT=="NAP":
  CPT=1
elif CPT=="ASY":
  CPT=2
elif CPT=="TA":
  CPT=3
else:
  print("ERROR FROM CPT")
if REC=="Normal":
  REC=0
elif REC=="ST":
  REC=1
elif REC=="LVH":
  REC=2
if EA == "Y":
  EA=1
elif EA=="N":
  EA=0
if STS=="Up":
  STS=0
elif STS=="Flat":
  STS=1
elif STS=="Down":
  STS=2
if SMOKE=="Y":
  SMOKE=1
elif SMOKE=="N":
  SMOKE=0

time.sleep(1)
output.clear()

UI = model.predict([[Age,Sex,CPT,RBP,Chol,FBS,REC,MHR,EA,OP,STS,SMOKE]]).round()
if UI[0]==0:
  print("The person doesn't have Heart Disease")
elif UI[0]==1:
  print("The person have Heart Disease")
# Out:
# The person doesn't have Heart Disease

# %% [markdown]
# #Here you we can see that the prediction goes perfect and matches with data we have in testing data.

# %%
df.head(5)
# Out:
#    Age  Sex  ChestPainType  RestingBP  ...  Oldpeak  STSlope  Smoking  HeartDisease
# 0   40    1              0        140  ...      0.0        0        0             0
# 1   49    0              1        160  ...      1.0        1        0             1
# 2   37    1              0        130  ...      0.0        0        1             0
# 3   48    0              2        138  ...      1.5        1        0             1
# 4   54    1              1        150  ...      0.0        0        0             0
#
# [5 rows x 13 columns]

# %% [markdown]
# #**Comparing test data with predicted data**

# %%
preddf = {'Expected': testY, 'Got': Pred}
preddf = pd.DataFrame(data=preddf)
preddf.head()
# Out:
#      Expected  Got
# 308         1  1.0
# 352         1  1.0
# 666         0  0.0
# 911         1  1.0
# 814         1  0.0

# %% [markdown]
# #**Evaluating Model:**

# %% [markdown]
# #Now here we can check how accurate the model is :

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import r2_score, mean_squared_error,accuracy_score
pred_y = model.predict(testX)
print('R2 Score = ',metrics.r2_score(testY,pred_y))
print('RMSE = ', np.sqrt(mean_squared_error(testY,pred_y)))
print('Accuracy score = ',metrics.accuracy_score(testY,pred_y.round()))
# Out:
# R2 Score =  0.45719704671214967
# RMSE =  0.3666467887814293
# Accuracy score =  0.8387096774193549

# %%
cm=metrics.confusion_matrix(testY, Pred, labels=[0, 1])
df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sb.heatmap(df_cm, annot=True,fmt='g')

# %% [markdown]
# ##**The confusion matrix :**
#
# ### No, No = True Positives (TP): We correctly predicted that they do not have Heart Disease 100.
#
# #### Yes, Yes = True Negatives (TN): We correctly predicted that they have Heart Disease 138.
#
# #### No, Yes = False Positives (FP): We incorrectly predicted that they don't have Heart Disease (a "Type I error") 26 Falsely predict positive Type I error.
#
# #### Yes, No = False Negatives (FN): We incorrectly predicted that they have Heart Disease (a "Type II error") 12 Falsely predict negative Type II error.

# %% [markdown]
# #**Training Set Score and Testing Set Score**

# %%
print("Training Set Score : ",model.score(trainX,trainY).round(3))
print("Testing Set Score : ",model.score(testX,testY).round(3))
# Out:
# Training Set Score :  0.522
# Testing Set Score :  0.457

# %% [markdown]
# ##**Wrong Predictions :**

# %%
wrongpred = 0
A = testY.to_numpy()
for i in range(len(Pred)):
    if (Pred[i] != A[i]):
        wrongpred += 1        
print("Number of wrong predictions : ",wrongpred)
# Out:
# Number of wrong predictions :  30

# %% [markdown]
# #**Conclusion:**
# In this Project we have imported heartdisease data csv file and imported it then filtered the dataset and shaped data for performing linear regression and then we built linear regression model and finally we have predicted the heart disease of a person whether he have the heart disease or not.If he have the heart disease prediction returns 1 if not it prediction returns 0 .
